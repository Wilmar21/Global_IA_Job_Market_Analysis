# %%
import pandas
# ANALISIS EXPLORATORIO EDA - DATASET IA_JOBS
import pandas as pd
jobsDatesetOriginal = pandas.read_csv('ai_job_dataset.csv', encoding='utf-8', low_memory=False)

# Mostramos los primeros datos del dataset
print("DATASET IA JOBS")
jobsDatesetOriginal.head()
# Out:
# DATASET IA JOBS
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# ...

# %%
# Mostramos informacion general del dataset
print("INFORMACION GENERAL DE LAS COLUMNAS DATASET")
jobsDatesetOriginal.info()
# Out:
# INFORMACION GENERAL DE LAS COLUMNAS DATASET
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  15000 non-null  object
#  1   job_title               15000 non-null  object
#  2   salary_usd              15000 non-null  int64
#  3   salary_currency         15000 non-null  object
#  4   experience_level        15000 non-null  object
#  5   employment_type         15000 non-null  object
#  6   company_location        15000 non-null  object
#  7   company_size            15000 non-null  object
#  8   employee_residence      15000 non-null  object
#  9   remote_ratio            15000 non-null  int64
#  10  required_skills         15000 non-null  object
#  11  education_required      15000 non-null  object
#  12  years_experience        15000 non-null  int64
# ...

# %%
# Realizamos un analisis exploratorio variables categoricas
print("ANALISIS EXPLORATORIO CATEGORICAS")
jobsDatesetOriginal.describe(include=['object', 'category'])
# Out:
# ANALISIS EXPLORATORIO CATEGORICAS
#          job_id                    job_title salary_currency experience_level  \
# count     15000                        15000           15000            15000
# unique    15000                           20               3                4
# top     AI15000  Machine Learning Researcher             USD               MI
# freq          1                          808           11957             3781
#
#        employment_type company_location company_size employee_residence  \
# count            15000            15000        15000              15000
# unique               4               20            3                 20
# top                 FT          Germany            S             Sweden
# freq              3812              814         5007                790
#
#                     required_skills education_required industry posting_date  \
# count                         15000              15000    15000        15000
# ...

# %%
# Realizamos un analisis exploratorio variables numericas
print("ANALISIS EXPLORATORIO NUMERICAS")
jobsDatesetOriginal.describe()
# Out:
# ANALISIS EXPLORATORIO NUMERICAS
#           salary_usd  remote_ratio  years_experience  job_description_length  \
# count   15000.000000  15000.000000      15000.000000            15000.000000
# mean   115348.965133     49.483333          6.253200             1503.314733
# std     60260.940438     40.812712          5.545768              576.127083
# min     32519.000000      0.000000          0.000000              500.000000
# 25%     70179.750000      0.000000          2.000000             1003.750000
# 50%     99705.000000     50.000000          5.000000             1512.000000
# 75%    146408.500000    100.000000         10.000000             2000.000000
# max    399095.000000    100.000000         19.000000             2499.000000
#
#        benefits_score
# count    15000.000000
# mean         7.504273
# std          1.450870
# min          5.000000
# 25%          6.200000
# 50%          7.500000
# 75%          8.800000
# max         10.000000

# %%
# Conteo de variables unicas
print("CONTEO DE VARIABLES UNICAS")
jobsDatesetOriginal.nunique().to_frame("Conteo variables unicas")
# Out:
# CONTEO DE VARIABLES UNICAS
#                         Conteo variables unicas
# job_id                                    15000
# job_title                                    20
# salary_usd                                14315
# salary_currency                               3
# experience_level                              4
# employment_type                               4
# company_location                             20
# company_size                                  3
# employee_residence                           20
# remote_ratio                                  3
# required_skills                           13663
# education_required                            4
# years_experience                             20
# industry                                     15
# posting_date                                486
# application_deadline                        543
# job_description_length                     2000
# benefits_score                               51
# ...

# %%
# Tipos de variables unicas
print("TIPOS DE VARIABLES UNICAS")
jobsDatesetOriginal.apply(pandas.unique).to_frame("Tipos unicas")
# Out:
# TIPOS DE VARIABLES UNICAS
#                                                              Tipos unicas
# job_id                  [AI00001, AI00002, AI00003, AI00004, AI00005, ...
# job_title               [AI Research Scientist, AI Software Engineer, ...
# salary_usd              [90376, 61895, 152626, 80215, 54624, 123574, 7...
# salary_currency                                           [USD, EUR, GBP]
# experience_level                                         [SE, EN, MI, EX]
# employment_type                                          [CT, FL, PT, FT]
# company_location        [China, Canada, Switzerland, India, France, Ge...
# company_size                                                    [M, L, S]
# employee_residence      [China, Ireland, South Korea, India, Singapore...
# remote_ratio                                                 [50, 100, 0]
# required_skills         [Tableau, PyTorch, Kubernetes, Linux, NLP, Dee...
# ...

# %%
# Interpretacion de las distribuciones de las variables numericas
import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy.stats as stats
import numpy as np

# Histogramas
jobsDatesetColumnasNumericas = jobsDatesetOriginal.drop(columns=['job_id', 'job_title', 'salary_currency', 'experience_level', 'employment_type', 'company_location', 'company_size', 'employee_residence', 'required_skills','education_required','industry','posting_date','application_deadline','company_name'])

plt.figure(figsize=(12, 10))
jobsDatesetColumnasNumericas.hist(bins=30, figsize=(12, 10))

plt.suptitle('Distribucion de las variables numericas IA JOBS - Histogramas')
plt.tight_layout()
plt.show()

# QQ Plots
numeric_columns = jobsDatesetColumnasNumericas.select_dtypes(include='number').columns
num_cols = len(numeric_columns)
cols = 2
rows = math.ceil(num_cols / cols)
plt.figure(figsize=(cols * 6, rows * 4))

for i, column in enumerate(numeric_columns, 1):
    plt.subplot(rows, cols, i)
    stats.probplot(jobsDatesetColumnasNumericas[column], dist="norm", plot=plt)
    plt.title(f"QQ Plot - {column}")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('QQ Plots de Variables Numéricas', fontsize=16)
plt.show()

# Subplots
numeric_columns = jobsDatesetColumnasNumericas.select_dtypes(include='number').columns
num_cols = len(numeric_columns)
cols = 2
rows = math.ceil(num_cols / cols)
plt.figure(figsize=(12, rows * 4))

for i, column in enumerate(numeric_columns, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(data=jobsDatesetColumnasNumericas[column], color='skyblue')
    plt.title(column)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle("Distribución de las Variables Numéricas en el Dataset de IA JOBS", fontsize=16)
plt.show()

# %%
# Interpretacion de las distribuciones de las variables Categoricas
jobsDatesetColumnasCategoricas = jobsDatesetOriginal.drop(columns=['salary_usd', 'remote_ratio', 'years_experience', 'job_description_length', 'benefits_score'])

jobsDatesetColumnasCategoricas.info()

# nivel de experiencia
plt.figure(figsize=(10, 4))
sns.countplot(y='experience_level', data=jobsDatesetColumnasCategoricas, order=jobsDatesetColumnasCategoricas['experience_level'].value_counts().index, hue='experience_level', dodge=False)
plt.title('Distribución IA JOBS', fontsize=16)
plt.xlabel('Cantidad de IA JOBS', fontsize=14)
plt.ylabel('experience_level', fontsize=14)
plt.legend([], [], frameon=False)  # Oculta la leyenda innecesaria
plt.show()

# nivel de educacion requerido
plt.figure(figsize=(10, 4))
sns.countplot(y='education_required', data=jobsDatesetColumnasCategoricas, order=jobsDatesetColumnasCategoricas['education_required'].value_counts().index, hue='education_required', dodge=False)
plt.title('Distribución IA JOBS', fontsize=16)
plt.xlabel('Cantidad de IA JOBS', fontsize=14)
plt.ylabel('education_required', fontsize=14)
plt.legend([], [], frameon=False)  # Oculta la leyenda innecesaria
plt.show()

# tipo de empleo
plt.figure(figsize=(10, 4))
sns.countplot(y='employment_type', data=jobsDatesetColumnasCategoricas, order=jobsDatesetColumnasCategoricas['employment_type'].value_counts().index, hue='employment_type', dodge=False)
plt.title('Distribución IA JOBS', fontsize=16)
plt.xlabel('Cantidad de IA JOBS', fontsize=14)
plt.ylabel('employment_type', fontsize=14)
plt.legend([], [], frameon=False)  # Oculta la leyenda innecesaria
plt.show()

# nombre de la empresa
plt.figure(figsize=(10, 4))
sns.countplot(y='company_name', data=jobsDatesetColumnasCategoricas, order=jobsDatesetColumnasCategoricas['company_name'].value_counts().index, hue='company_name', dodge=False)
plt.title('Distribución IA JOBS', fontsize=16)
plt.xlabel('Cantidad de IA JOBS', fontsize=14)
plt.ylabel('company_name', fontsize=14)
plt.legend([], [], frameon=False)  # Oculta la leyenda innecesaria
plt.show()

# Comparando el numero combinaciones entre 2 columnas
contingency_table = pandas.crosstab(jobsDatesetColumnasCategoricas['education_required'], jobsDatesetColumnasCategoricas['experience_level'])
plt.figure(figsize=(14, 8))
sns.heatmap(contingency_table, annot=True, fmt='d', cmap='viridis')
plt.title('Relación entre la educacion requerida y el nivel de experiencia')
plt.xlabel('Nivel de experiencia')
plt.ylabel('Educacion requerida')
plt.show()

contingency_table = pandas.crosstab(jobsDatesetColumnasCategoricas['employment_type'], jobsDatesetColumnasCategoricas['experience_level'])
plt.figure(figsize=(14, 8))
sns.heatmap(contingency_table, annot=True, fmt='d', cmap='viridis')
plt.title('Relación entre el tipo de empleo y el nivel de experiencia')
plt.xlabel('Nivel de experiencia')
plt.ylabel('Tipo de empleo')
plt.show()

contingency_table = pandas.crosstab(jobsDatesetColumnasCategoricas['education_required'], jobsDatesetColumnasCategoricas['company_size'])
plt.figure(figsize=(14, 8))
sns.heatmap(contingency_table, annot=True, fmt='d', cmap='viridis')
plt.title('Relación entre la educacion requerida y el tamaño de la empresa')
plt.xlabel('Tamaño de la empresa')
plt.ylabel('Educacion requerida')
plt.show()

contingency_table = pandas.crosstab(jobsDatesetOriginal['employment_type'], jobsDatesetOriginal['remote_ratio'])
plt.figure(figsize=(14, 8))
sns.heatmap(contingency_table, annot=True, fmt='d', cmap='viridis')
plt.title('Relación entre el tipo de empleo y el porcentaje de remoto')
plt.xlabel('Porcentaje de remoto')
plt.ylabel('Tipo de empleo')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                15000 non-null  object
#  1   job_title             15000 non-null  object
#  2   salary_currency       15000 non-null  object
#  3   experience_level      15000 non-null  object
#  4   employment_type       15000 non-null  object
#  5   company_location      15000 non-null  object
#  6   company_size          15000 non-null  object
#  7   employee_residence    15000 non-null  object
#  8   required_skills       15000 non-null  object
#  9   education_required    15000 non-null  object
#  10  industry              15000 non-null  object
#  11  posting_date          15000 non-null  object
#  12  application_deadline  15000 non-null  object
#  13  company_name          15000 non-null  object
# dtypes: object(14)
# memory usage: 1.6+ MB

# %%
# Identificar valores nulos dentro de los datos
jobsDatesetOriginal.isnull().sum()
# Out:
# job_id                    0
# job_title                 0
# salary_usd                0
# salary_currency           0
# experience_level          0
# employment_type           0
# company_location          0
# company_size              0
# employee_residence        0
# remote_ratio              0
# required_skills           0
# education_required        0
# years_experience          0
# industry                  0
# posting_date              0
# application_deadline      0
# job_description_length    0
# benefits_score            0
# company_name              0
# dtype: int64

# %%
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

print("Visualizaciones para datos faltantes")
plt.figure(figsize=(15,10))
sns.heatmap(jobsDatesetOriginal.isnull(), cbar=False, cmap='Blues')
plt.show()
# Out:
# Visualizaciones para datos faltantes

# %%
# Calcular la matriz de correlación
numeric_df = jobsDatesetOriginal.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(24, 16))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Matriz de Correlación', fontsize=16)
plt.show()

# %%
# Analisis y manejo de datos duplicados
jobsDatasetClean = jobsDatesetOriginal.copy()

# Verificacion de datos duplicados en una columna
duplicadosCol = jobsDatasetClean.duplicated(subset=['job_title','company_name','company_location','employment_type','experience_level','salary_usd','posting_date','application_deadline']).sum()
print(f'Duplicados en las columnas: {duplicadosCol}')

# Verificacion de duplicados en filas
duplicadosFilas = jobsDatasetClean.duplicated().sum()
print(f'Duplicados en filas: {duplicadosFilas}')
# Out:
# Duplicados en las columnas: 0
# Duplicados en filas: 0

# %%
#4. Codificación de variables categóricas
from sklearn.preprocessing import LabelEncoder

nombreColumnas = ['job_title', 'experience_level', 'employment_type', 'company_location', 'company_size', 'education_required', 'industry', 'salary_currency', 'employee_residence','required_skills', 'company_name']
jobsDatasetLabelEncoder = jobsDatasetClean[nombreColumnas].copy()
jobsDatasetLabelEncoder.info()

encoder = LabelEncoder()
jobsDatasetLabelEncoder['job_title'] = encoder.fit_transform(jobsDatasetLabelEncoder['job_title'])
jobsDatasetLabelEncoder['experience_level'] = encoder.fit_transform(jobsDatasetLabelEncoder['experience_level'])
jobsDatasetLabelEncoder['employment_type'] = encoder.fit_transform(jobsDatasetLabelEncoder['employment_type'])
jobsDatasetLabelEncoder['company_location'] = encoder.fit_transform(jobsDatasetLabelEncoder['company_location'])
jobsDatasetLabelEncoder['company_size'] = encoder.fit_transform(jobsDatasetLabelEncoder['company_size'])
jobsDatasetLabelEncoder['education_required'] = encoder.fit_transform(jobsDatasetLabelEncoder['education_required'])
jobsDatasetLabelEncoder['salary_currency'] = encoder.fit_transform(jobsDatasetLabelEncoder['salary_currency'])
jobsDatasetLabelEncoder['industry'] = encoder.fit_transform(jobsDatasetLabelEncoder['industry'])
jobsDatasetLabelEncoder['employee_residence'] = encoder.fit_transform(jobsDatasetLabelEncoder['employee_residence'])
jobsDatasetLabelEncoder['required_skills'] = encoder.fit_transform(jobsDatasetLabelEncoder['required_skills'])
jobsDatasetLabelEncoder['company_name'] = encoder.fit_transform(jobsDatasetLabelEncoder['company_name'])

plt.figure(figsize=(12, 10))
jobsDatasetLabelEncoder.hist(bins=30, figsize=(12, 10))
plt.suptitle('Distribucion de las variables caterigoricas - Histogramas')
plt.tight_layout()  
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_title           15000 non-null  object
#  1   experience_level    15000 non-null  object
#  2   employment_type     15000 non-null  object
#  3   company_location    15000 non-null  object
#  4   company_size        15000 non-null  object
#  5   education_required  15000 non-null  object
#  6   industry            15000 non-null  object
#  7   salary_currency     15000 non-null  object
#  8   employee_residence  15000 non-null  object
#  9   required_skills     15000 non-null  object
#  10  company_name        15000 non-null  object
# dtypes: object(11)
# memory usage: 1.3+ MB

# %%
# Convertir Columnas categoricas a columnas numericas para poder interpretar su correlación
jobsDatasetClean['job_title'] = encoder.fit_transform(jobsDatasetClean['job_title'])
jobsDatasetClean['employment_type'] = encoder.fit_transform(jobsDatasetClean['employment_type'])
jobsDatasetClean['company_location'] = encoder.fit_transform(jobsDatasetClean['company_location'])
jobsDatasetClean['industry'] = encoder.fit_transform(jobsDatasetClean['industry'])
jobsDatasetClean['education_required'] = encoder.fit_transform(jobsDatasetClean['education_required'])
jobsDatasetClean['experience_level'] = encoder.fit_transform(jobsDatasetClean['experience_level'])
jobsDatasetClean['company_size'] = encoder.fit_transform(jobsDatasetClean['company_size'])

# Calcular la matriz de correlación
numeric_df = jobsDatasetClean.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(24, 16))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Matriz de Correlación', fontsize=16)
plt.show()

# %%
# 5. Detección y manejo de valores atípicos
from scipy.stats import zscore
import numpy as np
from pyod.models.mad import MAD

jobsDatasetCleanOutliers = jobsDatasetClean.copy()

# Histogramas
plt.figure(figsize=(12, 10))
jobsDatasetCleanOutliers.hist(bins=30, figsize=(12, 10))
plt.suptitle('Distribucion de las variables numericas IA JOBS - Histogramas')
plt.tight_layout()
plt.show()
# boxplots
numeric_columns = jobsDatasetCleanOutliers.select_dtypes(include='number').columns
num_cols = len(numeric_columns)
cols = 2
rows = math.ceil(num_cols / cols)
plt.figure(figsize=(12, rows * 4))

for i, column in enumerate(numeric_columns, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(data=jobsDatasetCleanOutliers[column], color='skyblue')
    plt.title(column)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle("Distribución de las Variables Numéricas en el Dataset de IA JOBS", fontsize=16)
plt.show()

print('VALORES ORIGINALES PARA LA VARIABLE SALARIO')
columna = jobsDatasetCleanOutliers['salary_usd']
plt.figure(figsize=(6, 4))  # Tamaño de la figura
columna.hist(bins=30)  # Puedes cambiar el número de bins según lo que necesites
plt.title('Histograma Amount')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
sns.boxplot(x=jobsDatasetCleanOutliers['salary_usd'])
plt.show()

# Aplicacion modelo Z-SCORE para el manejo de outliers
print('VALORES Z-Score')
jobsDatasetCleanOutliers['zscore'] = zscore(jobsDatasetCleanOutliers['salary_usd'])
outliers = jobsDatasetCleanOutliers[jobsDatasetCleanOutliers['zscore'].abs() > 3]
z_scores = zscore(jobsDatasetCleanOutliers['salary_usd'])
abs_z_scores = np.abs(z_scores)
print(f'Numero de outliers Z-Score: {len(outliers)}')

jobsDatasetConZScore = pandas.merge(jobsDatasetCleanOutliers, outliers, how='left', indicator=True).query('_merge == "left_only"').drop('_merge', axis=1)

columna = jobsDatasetConZScore['salary_usd']
plt.figure(figsize=(6, 4))  # Tamaño de la figura
columna.hist(bins=30)  # Puedes cambiar el número de bins según lo que necesites
plt.title('Histograma Amount diferencia_1')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
sns.boxplot(x=jobsDatasetConZScore['salary_usd'])
plt.show()

# Aplicacion modelo Z-SCORE mejorado para el manejo de outliers
print('VALORES Z-Score Mejorado')
mad = MAD(threshold = 3.5)
total_reshaped = jobsDatasetCleanOutliers['salary_usd'].values.reshape(-1, 1)
labels = mad.fit(total_reshaped).labels_
print(f'Numero de outliers Z-Score Modificado: {labels.sum()}')

jobsDatasetConZScoreMejorado = jobsDatasetCleanOutliers.copy()
jobsDatasetConZScoreMejorado = jobsDatasetConZScoreMejorado[labels == 0]
columna = jobsDatasetConZScoreMejorado['salary_usd']
plt.figure(figsize=(6, 4))
columna.hist(bins=30)
plt.title('Histograma Amount')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

sns.boxplot(x=jobsDatasetConZScoreMejorado['salary_usd'])
plt.show()

# Aplicacion modelo IQR - Rango intercuartilico para el manejo de outliers
print('VALORES IQR - Rango intercuartílico')
Q1 = jobsDatasetCleanOutliers['salary_usd'].quantile(0.25)
Q3 = jobsDatasetCleanOutliers['salary_usd'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

jobsDatasetConIQR = jobsDatasetCleanOutliers[(jobsDatasetCleanOutliers['salary_usd'] < lower_bound) | (jobsDatasetCleanOutliers['salary_usd'] > upper_bound)]
print("Outliers según IQR:")
print(len(jobsDatasetConIQR))

DF_jobsDatasetConIQR = jobsDatasetCleanOutliers[(jobsDatasetCleanOutliers['salary_usd'] >= lower_bound) & (jobsDatasetCleanOutliers['salary_usd'] <= upper_bound)]
print("Datos sin outliers:")
print(len(DF_jobsDatasetConIQR))

columna = DF_jobsDatasetConIQR['salary_usd']
plt.figure(figsize=(6, 4))  # Tamaño de la figura
columna.hist(bins=30)  # Puedes cambiar el número de bins según lo que necesites
plt.title('Histograma Amount')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()

sns.boxplot(x=DF_jobsDatasetConIQR['salary_usd'])
plt.show()
# Out:
# VALORES ORIGINALES PARA LA VARIABLE SALARIO
# VALORES Z-Score
# Numero de outliers Z-Score: 203
# VALORES Z-Score Mejorado
# Numero de outliers Z-Score Modificado: 335
# C:\Users\USUARIO\Universidad\POSGRADO\Semestre 1\4. Modelos analiticos\proyecto\venv\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\USUARIO\Universidad\POSGRADO\Semestre 1\4. Modelos analiticos\proyecto\venv\Lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# VALORES IQR - Rango intercuartílico
# Outliers según IQR:
# 483
# Datos sin outliers:
# 14517

# %%
# 6. Normalizacion y escalado

jobsDatasetRatioEscaled = jobsDatasetClean

jobsDatasetRatioEscaled['remote_ratio'] = jobsDatasetRatioEscaled['remote_ratio'] / 100

jobsDataset_transformadas = jobsDatasetClean

print('VALORES ORIGINALES PARA EL SALARIO')
columna = jobsDatasetCleanOutliers['salary_usd']
plt.figure(figsize=(6, 4))  # Tamaño de la figura
columna.hist(bins=30)  # Puedes cambiar el número de bins según lo que necesites
plt.title('Histograma Amount')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
sns.boxplot(x=jobsDatasetCleanOutliers['salary_usd'])
plt.show()

# Transformada Logaritmica por tener un sesgo positivo fuerte
jobsDataset_transformadas['salary_usd'] = np.log1p(jobsDataset_transformadas['salary_usd'])

print('VALORES CON LA TRANSFORMADA EN EL SALARIO')
columna = jobsDataset_transformadas['salary_usd']
plt.figure(figsize=(6, 4))  # Tamaño de la figura
columna.hist(bins=30)  # Puedes cambiar el número de bins según lo que necesites
plt.title('Histograma Amount')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
sns.boxplot(x=jobsDataset_transformadas['salary_usd'])
plt.show()

print('VALORES ORIGINALES PARA LOS AÑOS DE EXPERIACIA')
columna = jobsDatasetCleanOutliers['years_experience']
plt.figure(figsize=(6, 4))  # Tamaño de la figura
columna.hist(bins=30)  # Puedes cambiar el número de bins según lo que necesites
plt.title('Histograma Amount')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
sns.boxplot(x=jobsDatasetCleanOutliers['years_experience'])
plt.show()

# Transformada raiz cuadrada por tener un sesgo positivo moderado
jobsDataset_transformadas['years_experience'] = np.sqrt(jobsDataset_transformadas['years_experience'])

print('VALORES CON LA TRANFORMADA EN LOS AÑOS DE EXPERIENCIA')
columna = jobsDataset_transformadas['years_experience']
plt.figure(figsize=(6, 4))  # Tamaño de la figura
columna.hist(bins=30)  # Puedes cambiar el número de bins según lo que necesites
plt.title('Histograma Amount')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.show()
sns.boxplot(x=jobsDataset_transformadas['years_experience'])
plt.show()
# Out:
# VALORES ORIGINALES PARA EL SALARIO
# VALORES CON LA TRANSFORMADA EN EL SALARIO
# VALORES ORIGINALES PARA LOS AÑOS DE EXPERIACIA
# VALORES CON LA TRANFORMADA EN LOS AÑOS DE EXPERIENCIA

# %%
# IMPLEMENTACION DEL MODELO ANALITICO

#jobsDatesetOriginal.nunique().to_frame("Conteo variables unicas")

nombreColumnas = ['job_title', 'experience_level', 'years_experience', 'employment_type', 'education_required', 'remote_ratio', 'company_location', 'company_size','benefits_score', 'salary_usd']
jobsDatesetModeloRegresion = jobsDatasetClean[nombreColumnas].copy()

# Calcular la matriz de correlación
numeric_df = jobsDatesetModeloRegresion.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(24, 16))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Matriz de Correlación', fontsize=16)
plt.show()

# %%
# Implementacion regresion lineal

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

nombreColumnas = ['job_title', 'experience_level', 'years_experience', 'employment_type', 'education_required', 'remote_ratio', 'company_location', 'company_size','benefits_score', 'salary_usd']
jobsDatesetModeloRegresion = jobsDatasetClean[nombreColumnas].copy()

variableObjetivo = jobsDatesetModeloRegresion['salary_usd']
jobsDatesetModeloRegresion = jobsDatesetModeloRegresion.drop(columns=['salary_usd'])

# Creacion de los conjuntos de datos para el modelo de prediccion
X_train, X_test, y_train, y_test = train_test_split(jobsDatesetModeloRegresion, variableObjetivo, test_size=0.2,
                                                    random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Evaluación del Modelo:")
print(f"MAE (Error Absoluto Medio): {mae:.2f}")
print(f"MSE (Error Cuadrático Medio): {mse:.2f}")
print(f"R² (Coeficiente de Determinación): {r2:.2f}")

evaluarCasoMediaDataset = pandas.DataFrame({
    'job_title': [9],
    'experience_level': [1],
    'years_experience': [2],
    'employment_type': [1],
    'education_required': [1],
    'remote_ratio': [0.5],
    'company_location': [9],
    'company_size': [1],
    'benefits_score': [7]
}
)

evaluarCasoDos = pandas.DataFrame({
    'job_title': [19],
    'experience_level': [3],
    'years_experience': [4],
    'employment_type': [3],
    'education_required': [3],
    'remote_ratio': [1.0],
    'company_location': [19],
    'company_size': [10],
    'benefits_score': [2]
}
)

evaluarCasoDataset005 = pandas.DataFrame({
    'job_title': [1],
    'experience_level': [0],
    'years_experience': [0.000000],
    'employment_type': [3],
    'education_required': [2],
    'remote_ratio': [1.0],
    'company_location': [6],
    'company_size': [2],
    'benefits_score': [6.6]
}
)

prediccion = model.predict(evaluarCasoMediaDataset)
print("Posible Salario (media): ", prediccion[0])

prediccionDos = model.predict(evaluarCasoDos)
print("Posible Salario Caso 2: ", prediccionDos[0])

prediccionTres = model.predict(evaluarCasoDataset005)
print("Posible Slario Caso 3 (005): ", prediccionTres[0])
# Out:
# Evaluación del Modelo:
# MAE (Error Absoluto Medio): 0.23
# MSE (Error Cuadrático Medio): 0.08
# R² (Coeficiente de Determinación): 0.68
# Posible Salario (media):  11.48562530589665
# Posible Salario Caso 2:  11.075796880723953
# Posible Slario Caso 3 (005):  10.70276852237726

# %%
# Implementacion regresion lineal con random forest

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

nombreColumnas = ['job_title', 'experience_level', 'years_experience', 'employment_type', 'education_required', 'remote_ratio', 'company_location', 'company_size','benefits_score', 'salary_usd']
jobsDatesetModeloRandomForest = jobsDatasetClean[nombreColumnas].copy()

variableObjetivo = jobsDatesetModeloRandomForest['salary_usd']
jobsDatesetModeloRandomForest = jobsDatesetModeloRandomForest.drop(columns=['salary_usd'])

# Creacion de los conjuntos de datos para el modelo de prediccion
X_train, X_test, y_train, y_test = train_test_split(jobsDatesetModeloRandomForest, variableObjetivo, test_size=0.2,
                                                    random_state=42)
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Evaluación del Modelo:")
print(f"MAE (Error Absoluto Medio): {mae:.2f}")
print(f"MSE (Error Cuadrático Medio): {mse:.2f}")
print(f"R² (Coeficiente de Determinación): {r2:.2f}")

evaluarCasoMediaDataset = pandas.DataFrame({
    'job_title': [9],
    'experience_level': [1],
    'years_experience': [2],
    'employment_type': [1],
    'education_required': [1],
    'remote_ratio': [0.5],
    'company_location': [9],
    'company_size': [1],
    'benefits_score': [7]
}
)

evaluarCasoDos = pandas.DataFrame({
    'job_title': [19],
    'experience_level': [3],
    'years_experience': [4],
    'employment_type': [3],
    'education_required': [3],
    'remote_ratio': [1.0],
    'company_location': [19],
    'company_size': [10],
    'benefits_score': [2]
}
)

evaluarCasoDataset005 = pandas.DataFrame({
    'job_title': [1],
    'experience_level': [0],
    'years_experience': [0.000000],
    'employment_type': [3],
    'education_required': [2],
    'remote_ratio': [1.0],
    'company_location': [6],
    'company_size': [2],
    'benefits_score': [6.6]
}
)

prediccion = model.predict(evaluarCasoMediaDataset)
print("Posible Salario (media): ", prediccion[0])

prediccionDos = model.predict(evaluarCasoDos)
print("Posible Salario Caso 2: ", prediccionDos[0])

prediccionTres = model.predict(evaluarCasoDataset005)
print("Posible Slario Caso 3 (005): ", prediccionTres[0])
# Out:
# Evaluación del Modelo:
# MAE (Error Absoluto Medio): 0.13
# MSE (Error Cuadrático Medio): 0.02
# R² (Coeficiente de Determinación): 0.90
# Posible Salario (media):  10.919210418510747
# Posible Salario Caso 2:  12.076625988660915
# Posible Slario Caso 3 (005):  10.90866405587083

# %%
# Implementacion regresion lineal con arbol de decision

from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

nombreColumnas = ['job_title', 'experience_level', 'years_experience', 'employment_type', 'education_required', 'remote_ratio', 'company_location', 'company_size','benefits_score', 'salary_usd']
jobsDatesetModeloTreeDecision = jobsDatasetClean[nombreColumnas].copy()

variableObjetivo = jobsDatesetModeloTreeDecision['salary_usd']
jobsDatesetModeloTreeDecision = jobsDatesetModeloTreeDecision.drop(columns=['salary_usd'])

# Creacion de los conjuntos de datos para el modelo de prediccion
X_train, X_test, y_train, y_test = train_test_split(jobsDatesetModeloTreeDecision, variableObjetivo, test_size=0.2, random_state=42)

arbolModel = DecisionTreeRegressor(max_depth=20, random_state=42)
arbolModel.fit(X_train, y_train)

y_pred = arbolModel.predict(X_test)

print("Evaluación del Árbol de Regresión:")
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))

evaluarCasoMediaDataset = pandas.DataFrame({
    'job_title': [9],
    'experience_level': [1],
    'years_experience': [2],
    'employment_type': [1],
    'education_required': [1],
    'remote_ratio': [0.5],
    'company_location': [9],
    'company_size': [1],
    'benefits_score': [7]
}
)

evaluarCasoDos = pandas.DataFrame({
    'job_title': [19],
    'experience_level': [3],
    'years_experience': [4],
    'employment_type': [3],
    'education_required': [3],
    'remote_ratio': [1.0],
    'company_location': [19],
    'company_size': [10],
    'benefits_score': [2]
}
)

evaluarCasoDataset005 = pandas.DataFrame({
    'job_title': [1],
    'experience_level': [0],
    'years_experience': [0.000000],
    'employment_type': [3],
    'education_required': [2],
    'remote_ratio': [1.0],
    'company_location': [6],
    'company_size': [2],
    'benefits_score': [6.6]
}
)

prediccion = arbolModel.predict(evaluarCasoMediaDataset)
print("Posible Salario (media): ", prediccion[0])

prediccionDos = arbolModel.predict(evaluarCasoDos)
print("Posible Salario Caso 2: ", prediccionDos[0])

prediccionTres = arbolModel.predict(evaluarCasoDataset005)
print("Posible Salario Caso 3 (005): ", prediccionTres[0])

plt.figure(figsize=(20,10))
plot_tree(arbolModel, feature_names=jobsDatesetModeloTreeDecision.columns, filled=True, fontsize=10)
plt.show()
# Out:
# Evaluación del Árbol de Regresión:
# MAE: 0.16582591743650046
# MSE: 0.042908949803558576
# R²: 0.8254410423436428
# Posible Salario (media):  10.615411075092878
# Posible Salario Caso 2:  11.842826156208403
# Posible Salario Caso 3 (005):  10.90824693239789

# %%
#jobsDatasetClean.to_excel('JobsIA.xlsx', index=False)

# %%
# EJECUCION MODELO DE AGRUPAMIENTO - KMEANS

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Se eligen las columnas por las cuales se va aplicar el modelo de agrupamiento
nombreColumnas = ['salary_usd', 'years_experience', 'remote_ratio', 'experience_level','education_required','employment_type','company_size']
jobsDatesetKmeans = jobsDatasetClean[nombreColumnas].copy()

# Se aplica un valor de escalado estadar a los datos del dataframe para mejorar la efectividad del KMeans
scaler = StandardScaler()
jobsDatesetKmeansScaler = scaler.fit_transform(jobsDatesetKmeans)

# Creamos el modelo de Kmeans
kmeansJobsDataset = KMeans(n_clusters=3, random_state=42)
jobsDatasetClean['job_segment'] = kmeansJobsDataset.fit_predict(jobsDatesetKmeansScaler)

jobsDatasetClean.info()

plt.figure(figsize=(10, 6))
plt.scatter(jobsDatasetClean['salary_usd'], jobsDatasetClean['years_experience'], c=jobsDatasetClean['job_segment'], cmap='viridis', s=10)
plt.colorbar(label='job_segment')
plt.title('Clustering de IA Jobs (K-Means)')
plt.xlabel('salary_usd')
plt.ylabel('years_experience')
plt.show()

# Ver distribucion de los datos categoricos
pca = PCA(n_components=2)
X_pca = pca.fit_transform(jobsDatesetKmeansScaler)
labels = kmeansJobsDataset.labels_

plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', s=50)
plt.title('Clusters encontrados por KMeans (PCA)')
plt.xlabel('Componente principal 1')
plt.ylabel('Componente principal 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

centroids_pca = pca.transform(kmeansJobsDataset.cluster_centers_)

plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', s=50, alpha=0.6)
plt.scatter(centroids_pca[:, 0], centroids_pca[:, 1], c='red', s=200, marker='X', label='Centroides')
plt.title('Clusters y Centroides (PCA)')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  15000 non-null  object
#  1   job_title               15000 non-null  int64
#  2   salary_usd              15000 non-null  float64
#  3   salary_currency         15000 non-null  object
#  4   experience_level        15000 non-null  int64
#  5   employment_type         15000 non-null  int64
#  6   company_location        15000 non-null  int64
#  7   company_size            15000 non-null  int64
#  8   employee_residence      15000 non-null  object
#  9   remote_ratio            15000 non-null  float64
#  10  required_skills         15000 non-null  object
#  11  education_required      15000 non-null  int64
#  12  years_experience        15000 non-null  float64
#  13  industry                15000 non-null  int64
# ...

# %%
#jobsDatasetClean.to_excel('IaJobsClusters.xlsx', index=False)

# %%
# Implementacion modelo analitico - Modelo de clasificacion - Maquinas de vectores de soporte SVM

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

nombreColumnas = ['salary_usd', 'years_experience', 'remote_ratio', 'experience_level','education_required','employment_type','company_size','job_segment']
jobsDatasetCleanClasificacion = jobsDatasetClean[nombreColumnas].copy()

variableObjetivo = jobsDatasetCleanClasificacion['job_segment']
jobsDatasetCleanClasificacion = jobsDatasetCleanClasificacion.drop(columns=['job_segment'])

X_train, X_test, y_train, y_test = train_test_split(jobsDatasetCleanClasificacion, variableObjetivo, test_size=0.2, random_state=42)

svmModel = SVC(kernel='linear', C = 1.0 ,random_state=42)
svmModel.fit(X_train, y_train)

y_pred = svmModel.predict(X_test)

print("Matriz confuncision: ")
print(confusion_matrix(y_test, y_pred))

print("Reporte clasificacion: ")
print(classification_report(y_test, y_pred))

evaluarCasoPrueba = pandas.DataFrame({
    'salary_usd': [11.653105],
    'years_experience': [3.872983],
    'remote_ratio': [0.0],
    'experience_level': [1],
    'education_required': [2],
    'employment_type': [0],
    'company_size': [2],
}
)

prediccionSVM = svmModel.predict(evaluarCasoPrueba)
print("Posible Segmento de trabajo", prediccionSVM[0])

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_test)

plt.figure(figsize=(8,6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y_pred, palette='coolwarm')
plt.title("Predicciones del modelo SVM en 2D")
plt.show()
# Out:
# Matriz confuncision:
# [[ 722    0    0]
#  [   0 1497    0]
#  [   0    0  781]]
# Reporte clasificacion:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       722
#            1       1.00      1.00      1.00      1497
#            2       1.00      1.00      1.00       781
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
#
# Posible Segmento de trabajo 2

# %%
# Aplicacion modelo de clasificacion Regresion logistica
from sklearn.linear_model import LogisticRegression

jobsDatesetLogistica = jobsDatasetClean.copy()

mapeo_categorias = {
    0: 'Entry',
    1: 'Executive',
    2: 'Mid',
    3: 'Senior'
}

jobsDatesetLogistica['experience_level'] = jobsDatesetLogistica['experience_level'].map(mapeo_categorias)

plt.figure(figsize=(10, 6))
sns.countplot(y='experience_level', data=jobsDatesetLogistica, order=jobsDatesetLogistica['experience_level'].value_counts().index, hue='experience_level', dodge=False)
plt.title('Nivel de experiencia', fontsize=16)
plt.xlabel('Cantidad de JOBS', fontsize=14)
plt.ylabel('Nivel de experiencia', fontsize=14)
plt.legend([], [], frameon=False)  # Oculta la leyenda innecesaria
plt.show()

nombreColumnas = ['salary_usd', 'job_title', 'company_location', 'remote_ratio','years_experience', 'experience_level']
jobsDatesetLogistica = jobsDatesetLogistica[nombreColumnas].copy()

# Calcular la matriz de correlación
numeric_df = jobsDatesetLogistica.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_df.corr()
plt.figure(figsize=(24, 16))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Matriz de Correlación', fontsize=16)
plt.show()

variableObjetivo = jobsDatesetLogistica['experience_level']
jobsDatesetLogistica = jobsDatesetLogistica.drop(columns=['experience_level'])

# Creacion de los conjuntos de datos para el modelo de prediccion
X_train, X_test, y_train, y_test = train_test_split(jobsDatesetLogistica, variableObjetivo, test_size=0.2, random_state=42)

modelLogistica = LogisticRegression(max_iter=2000, random_state=42)
modelLogistica.fit(X_train, y_train)

y_pred = modelLogistica.predict(X_test)

print("Matriz confuncision: ")
print(confusion_matrix(y_test, y_pred))

print("Reporte clasificacion: ")
print(classification_report(y_test, y_pred))

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_test)

plt.figure(figsize=(8,6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y_pred, palette='coolwarm')
plt.title("Predicciones del modelo Regresion Logisitca en 2D")
plt.show()

evaluarCasoPrueba = pandas.DataFrame({
    'salary_usd': [11.935752],
    'job_title': [5],
    'company_location': [17],
    'remote_ratio': [0.0],
    'years_experience': [1.414214],
}
)

prediccionLogistic = modelLogistica.predict(evaluarCasoPrueba)
print("Posible Nivel de experiencia requerido ", prediccionLogistic[0])
# Out:
# Matriz confuncision:
# [[722   0   0   0]
#  [  0 776   0   5]
#  [  0   0 757   0]
#  [  0   3   1 736]]
# Reporte clasificacion:
#               precision    recall  f1-score   support
#
#        Entry       1.00      1.00      1.00       722
#    Executive       1.00      0.99      0.99       781
#          Mid       1.00      1.00      1.00       757
#       Senior       0.99      0.99      0.99       740
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
# Posible Nivel de experiencia requerido  Mid

# %%
jobsDatesetLogistica.head()
# Out:
#    salary_usd  job_title  company_location  remote_ratio  years_experience
# 0   11.411745          3                 3           0.5          3.000000
# 1   11.033211          4                 2           1.0          1.000000
# 2   11.935752          5                17           0.0          1.414214
# 3   11.292478         16                 8           0.5          2.645751
# 4   10.908247          1                 6           1.0          0.000000

# %%
#jobsDatesetLogistica.to_excel('IaJobsLogistica.xlsx', index=False)
